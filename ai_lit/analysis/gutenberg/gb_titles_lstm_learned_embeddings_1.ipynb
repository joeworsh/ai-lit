# %% [markdown]
# # Gutenberg Titles Dataset with LSTM
# LSTM analysis with the Gutenberg titles dataset. Using the following configuration:

# %%
# %matplotlib inline

import os
import sys
ai_lit_path = os.path.abspath(os.path.join(os.getcwd(), os.pardir, os.pardir, os.pardir))
print("Loading AI Lit system from path", ai_lit_path)
sys.path.append(ai_lit_path)

import tensorflow as tf

from ai_lit.analysis import analysis_util
from ai_lit.university.gutenberg import gb_titles_flat_lstm
# Out:
# Loading AI Lit system from path C:\Users\joewo\workspaces\python\ai_lit
# C:\Tools\Anaconda3\lib\site-packages\gensim\utils.py:855: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
# use the flags imported from the univserity and the model to set the configuration
tf.flags.FLAGS.vocab_count = 100
tf.flags.FLAGS.word_embedding_size=100
tf.flags.FLAGS.doc_embedding_size=50
tf.flags.FLAGS.batch_size = 32

dataset_wkspc = os.path.join(ai_lit_path, 'workspace', 'gb_input')
training_wkspc = os.path.join(ai_lit_path, 'workspace', 'gutenberg_titles')
model_name = 'lstm_l2_learned_embedding'
evaluation_name = 'standard_eval'
univ = gb_titles_flat_lstm.GbTitlesFlatLstmUniversity(model_name, training_wkspc, dataset_wkspc)
accuracy, f1, cm = analysis_util.train_and_evaluate(univ, model_name, evaluation_name, save_rate=None, eval_rate=None)
# Out:
# Validation Step
# Targets:
# [1 1 3 3 1 5 0 3 2 2 3 4 1 1 1 2 4 5 1 2 0 0 1 2 3 1 1 5 0 3 2 1]
# Predictions:
# [4 4 2 4 3 4 3 4 2 1 4 1 1 3 4 3 4 1 2 3 3 3 4 1 3 3 3 3 3 3 3 4]
# Loss 1.81189, Acc 0.15625
#
# Testing examples exhausted
# Shutting down all network threads
# Accuracy: 0.224169921875
# F1: 0.19530750596

# %%
# use the flags imported from the univserity and the model to set the configuration
tf.flags.FLAGS.vocab_count = 500
tf.flags.FLAGS.word_embedding_size=50
tf.flags.FLAGS.doc_embedding_size=50
tf.flags.FLAGS.batch_size = 32

univ = gb_titles_flat_lstm.GbTitlesFlatLstmUniversity(model_name, training_wkspc, dataset_wkspc)
accuracy, f1, cm = analysis_util.train_and_evaluate(univ, model_name, evaluation_name, save_rate=None, eval_rate=None)
# Out:
# Validation Step
# Targets:
# [4 1 0 4 1 2 0 3 1 5 2 5 5 0 5 1 0 1 3 3 2 1 0 4 3 1 2 2 0 2 2 3]
# Predictions:
# [1 1 4 2 4 2 3 2 4 5 2 4 3 3 3 3 1 5 3 1 3 1 1 4 2 1 1 2 3 2 3 2]
# Loss 1.84905, Acc 0.3125
#
# Testing examples exhausted
# Shutting down all network threads
# Accuracy: 0.28076171875
# F1: 0.268196183721

# %%
# use the flags imported from the univserity and the model to set the configuration
tf.flags.FLAGS.vocab_count = 1000
tf.flags.FLAGS.word_embedding_size=100
tf.flags.FLAGS.doc_embedding_size=100
tf.flags.FLAGS.batch_size = 32

univ = gb_titles_flat_lstm.GbTitlesFlatLstmUniversity(model_name, training_wkspc, dataset_wkspc)
accuracy, f1, cm = analysis_util.train_and_evaluate(univ, model_name, evaluation_name, save_rate=None, eval_rate=None)
# Out:
# Validation Step
# Targets:
# [4 1 0 0 1 1 2 1 2 3 4 2 1 4 1 2 0 1 3 5 2 3 1 1 3 2 2 3 0 1 3 1]
# Predictions:
# [1 1 3 2 3 1 2 1 3 3 2 3 1 1 2 2 0 1 3 5 1 4 1 3 3 2 2 3 3 1 0 3]
# Loss 1.54996, Acc 0.53125
#
# Testing examples exhausted
# Shutting down all network threads
# Accuracy: 0.25669921875
# F1: 0.256183951849

# %%
# use the flags imported from the univserity and the model to set the configuration
tf.flags.FLAGS.vocab_count = 1000
tf.flags.FLAGS.word_embedding_size=25
tf.flags.FLAGS.doc_embedding_size=25
tf.flags.FLAGS.batch_size = 32

univ = gb_titles_flat_lstm.GbTitlesFlatLstmUniversity(model_name, training_wkspc, dataset_wkspc)
accuracy, f1, cm = analysis_util.train_and_evaluate(univ, model_name, evaluation_name, save_rate=None, eval_rate=None)
# Out:
# Validation Step
# Targets:
# [3 1 2 0 0 1 3 2 1 4 0 0 3 0 3 3 0 0 1 1 4 1 4 1 2 0 1 2 5 1 1 5]
# Predictions:
# [3 1 3 3 3 3 3 3 1 3 3 3 1 3 3 3 3 3 3 3 1 2 3 3 2 3 1 3 2 4 3 3]
# Loss 1.71805, Acc 0.25
#
# Testing examples exhausted
# Shutting down all network threads
# Accuracy: 0.28232421875
# F1: 0.2434146753

# %%
# use the flags imported from the univserity and the model to set the configuration
tf.flags.FLAGS.vocab_count = 5000
tf.flags.FLAGS.word_embedding_size=25
tf.flags.FLAGS.doc_embedding_size=50
tf.flags.FLAGS.batch_size = 32

univ = gb_titles_flat_lstm.GbTitlesFlatLstmUniversity(model_name, training_wkspc, dataset_wkspc)
accuracy, f1, cm = analysis_util.train_and_evaluate(univ, model_name, evaluation_name, save_rate=None, eval_rate=None)
# Out:
# Validation Step
# Targets:
# [1 2 2 0 1 4 4 0 5 5 0 0 4 0 1 3 3 3 0 1 1 3 1 1 1 0 1 2 0 2 2 0]
# Predictions:
# [1 2 2 5 3 0 3 3 1 5 4 3 5 0 2 2 0 3 0 1 1 5 2 5 3 0 1 3 3 3 2 4]
# Loss 1.96484, Acc 0.375
#
# Testing examples exhausted
# Shutting down all network threads
# Accuracy: 0.37888671875
# F1: 0.3701840599

# %%
# use the flags imported from the univserity and the model to set the configuration
tf.flags.FLAGS.vocab_count = 10000
tf.flags.FLAGS.word_embedding_size=25
tf.flags.FLAGS.doc_embedding_size=50
tf.flags.FLAGS.batch_size = 32

univ = gb_titles_flat_lstm.GbTitlesFlatLstmUniversity(model_name, training_wkspc, dataset_wkspc)
accuracy, f1, cm = analysis_util.train_and_evaluate(univ, model_name, evaluation_name, save_rate=None, eval_rate=None)
# Out:
# Validation Step
# Targets:
# [0 2 2 2 3 3 0 3 0 3 1 1 2 5 0 3 1 5 2 2 1 3 1 4 5 0 1 2 0 4 2 1]
# Predictions:
# [0 1 2 2 0 3 4 4 3 1 1 1 1 3 0 3 5 5 2 1 1 4 1 4 5 3 5 2 4 4 0 1]
# Loss 1.53129, Acc 0.53125
#
# Testing examples exhausted
# Shutting down all network threads
# Accuracy: 0.364970703125
# F1: 0.366767828539

# %% [markdown]
# ## Up to this point, the following configuration has performed the best:
# 1. tf.flags.FLAGS.vocab_count = 5000
# 1. tf.flags.FLAGS.word_embedding_size=25
# 1. tf.flags.FLAGS.doc_embedding_size=50
